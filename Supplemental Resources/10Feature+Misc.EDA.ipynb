# %%
import pandas as pd
from collections import Counter

# Load the datasets
df1 = pd.read_csv("../datasets/Raw_Datasets/zeekdata22fall.csv")
df2 = pd.read_csv("../datasets/Raw_Datasets/zeekdata24.csv")
df3 = pd.read_csv("../datasets/Raw_Datasets/zeekdata24fall.csv")
df4 = pd.read_csv("../datasets/Updated/final_train.csv") #Reconnaissance combined - train set
df5 = pd.read_csv("../datasets/Updated/test.csv") #Reconnaissance combined - test set
df6 = pd.read_csv("../datasets/final_train.csv") #Resource Development combined - train set
df7 = pd.read_csv("../datasets/test.csv") #Resource Development combined - test set

datasets = {
    "zeekdata22fall": df1,
    "zeekdata24": df2,
    "zeekdata24fall": df3
}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 from collections import Counter
#       4 # Load the datasets
# ----> 5 df1 = pd.read_csv("datasets/Raw_Datasets/zeekdata22fall.csv")
#       6 df2 = pd.read_csv("datasets/Raw_Datasets/zeekdata24.csv")
#       7 df3 = pd.read_csv("datasets/Raw_Datasets/zeekdata24fall.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/Raw_Datasets/zeekdata22fall.csv'

# %%
def combined_unique_values(column_name, *dfs):
    values = set()

    for df in dfs:
        if column_name in df.columns:
            values.update(df[column_name].dropna().unique())

    values = sorted(values)

    print(f"\nCombined unique values in '{column_name}' ({len(values)}):")
    for value in values:
        print(value)

    return values

# %%
def combined_unique_values_with_counts(column_name, *dfs):
    counter = Counter()

    
    for df in dfs:
        if column_name in df.columns:
            values = df[column_name].dropna().values
            counter.update(values)

    
    sorted_items = counter.most_common()

    print(f"\nCombined value counts for '{column_name}':")
    for value, count in sorted_items:
        print(f"{value}: {count}")

    
    return dict(counter)

# %%
for name, df in datasets.items():
    print(f"\n{'='*50}")
    print(name)
    print(f"{'='*50}")

    # Missing values per column
    missing_count = df.isnull().sum()

    # Keep only columns that have missing values
    missing_count = missing_count[missing_count > 0]

    if missing_count.empty:
        print("No missing values found.")
        continue

    # Calculate percentages only for columns with missing values
    missing_percent = (missing_count / len(df)) * 100

    summary = pd.DataFrame({
        "Missing Count": missing_count,
        "Missing Percentage (%)": missing_percent.round(2)
    })

    print("\nColumns with missing values:")
    print(summary)

    # Number of rows with at least one missing value
    rows_with_missing = df.isnull().any(axis=1).sum()
    print(f"\nInstances with at least one missing value: {rows_with_missing}")
    print(f"Total instances: {len(df)}")
# Out:
# ==================================================
# zeekdata22fall
# ==================================================
#
# Columns with missing values:
#             Missing Count  Missing Percentage (%)
# duration            15705                   45.05
# history               415                    1.19
# orig_bytes          15705                   45.05
# resp_bytes          15705                   45.05
# service             15836                   45.43
#
# Instances with at least one missing value: 16078
# Total instances: 34860
#
# ==================================================
# zeekdata24
# ==================================================
#
# Columns with missing values:
#             Missing Count  Missing Percentage (%)
# duration             2871                    2.99
# history                61                    0.06
# orig_bytes           2871                    2.99
# resp_bytes           2871                    2.99
# service              7721                    8.05
#
# Instances with at least one missing value: 9842
# Total instances: 95871
#
# ==================================================
# zeekdata24fall
# ==================================================
#
# Columns with missing values:
#             Missing Count  Missing Percentage (%)
# duration            62797                   43.11
# history               172                    0.12
# orig_bytes          62797                   43.11
# resp_bytes          62797                   43.11
# service             78449                   53.86
#
# Instances with at least one missing value: 86772
# Total instances: 145665

# %%
def analyze_label_characteristics(label_column, label_value, *dfs, min_frequency=0.90):
    # Combine all matching rows
    combined = pd.concat(
        [df[df[label_column] == label_value] for df in dfs],
        ignore_index=True
    )

    if combined.empty:
        print(f"No samples found for '{label_value}'.")
        return

    print("=" * 100)
    print(f"Analysis for '{label_value}'")
    print(f"Total Samples: {len(combined)}")
    print("=" * 100)

    results = []

    for col in combined.columns:

        if col == label_column:
            continue

        counts = combined[col].value_counts(dropna=False)

        if counts.empty:
            continue

        most_common_value = counts.index[0]
        most_common_count = counts.iloc[0]
        percentage = (most_common_count / len(combined)) * 100

        # Skip columns where every value is unique
        if most_common_count == 1:
            continue

        if percentage >= min_frequency * 100:
            results.append({
                "Column": col,
                "Most Common Value": most_common_value,
                "Count": most_common_count,
                "Percentage": percentage
            })

    if not results:
        print(f"No columns met the {min_frequency*100:.0f}% threshold.")
        return

    result_df = (
        pd.DataFrame(results)
        .sort_values(by="Percentage", ascending=False)
        .reset_index(drop=True)
    )

    print(result_df.to_string(index=False))

# %%
protocol_unique_values = combined_unique_values("proto", df1, df2, df3)
label_tactics = combined_unique_values("label_tactic", df1, df2, df3)
attack_counts = combined_unique_values_with_counts("label_tactic", df1, df2, df3)
# Out:
# Combined unique values in 'proto' (3):
# icmp
# tcp
# udp
#
# Combined unique values in 'label_tactic' (15):
# Collection
# Command and Control
# Credential Access
# Defense Evasion
# Discovery
# Execution
# Exfiltration
# Initial Access
# Lateral Movement
# Persistence
# Priviledge Escalation
# Privilege Escalation
# Reconnaissance
# Resource Development
# none
#
# Combined value counts for 'label_tactic':
# none: 138167
# Discovery: 67585
# Credential Access: 43495
# Resource Development: 13644
# Reconnaissance: 10690
# Defense Evasion: 873
# Initial Access: 617
# Privilege Escalation: 547
# Persistence: 336
# Priviledge Escalation: 326
# Lateral Movement: 40
# Execution: 32
# Exfiltration: 23
# Command and Control: 20
# Collection: 1

# %%
column_name = "label_tactic"
for name, df in datasets.items():
    print(f"\n{name}")
    print(df[column_name].value_counts(dropna=False))
# Out:
# zeekdata22fall
# label_tactic
# none                    17508
# Resource Development    13644
# Reconnaissance           2492
# Discovery                 861
# Defense Evasion           133
# Privilege Escalation      133
# Execution                  30
# Initial Access             19
# Command and Control        17
# Lateral Movement           11
# Persistence                10
# Collection                  1
# Credential Access           1
# Name: count, dtype: int64
#
# zeekdata24
# label_tactic
# none                     47906
# Credential Access        43494
# Reconnaissance            2909
# Initial Access             561
# Persistence                326
# Priviledge Escalation      326
# Defense Evasion            326
# Exfiltration                23
# Name: count, dtype: int64
#
# zeekdata24fall
# label_tactic
# none                    72753
# Discovery               66724
# Reconnaissance           5289
# Defense Evasion           414
# Privilege Escalation      414
# Initial Access             37
# Lateral Movement           29
# Command and Control         3
# Execution                   2
# Name: count, dtype: int64

# %%
print ("Reconnaissance combined - test set")
for tactic in sorted(set(df5["label_tactic"])):
    analyze_label_characteristics("label_tactic",tactic,df5)
    print("\n")
# Out:
# Reconnaissance combined - test set
# ====================================================================================================
# Analysis for 'Credential Access'
# Total Samples: 8699
# ====================================================================================================
#                 Column  Most Common Value  Count  Percentage
#             local_resp                  0   8699  100.000000
#         src_port_bin_1                  0   8699  100.000000
#         src_port_bin_2                  1   8699  100.000000
#         src_port_bin_3                  0   8699  100.000000
#        dest_port_bin_1                  0   8699  100.000000
#        dest_port_bin_2                  1   8699  100.000000
#        dest_port_bin_3                  0   8699  100.000000
#       duration_bin_0.0                  0   8699  100.000000
#     orig_bytes_bin_1.0                  1   8699  100.000000
#     orig_bytes_bin_2.0                  0   8699  100.000000
#   missed_bytes_bin_4.0                  0   8699  100.000000
#     orig_bytes_bin_6.0                  0   8699  100.000000
#      orig_pkts_bin_1.0                  0   8699  100.000000
#     resp_bytes_bin_0.0                  0   8699  100.000000
#     orig_bytes_bin_0.0                  0   8699  100.000000
#              history_D                  0   8699  100.000000
#          conn_state_S0                  0   8699  100.000000
#          conn_state_SH                  0   8699  100.000000
#         conn_state_SHR                  0   8699  100.000000
#         conn_state_OTH                  0   8699  100.000000
#         conn_state_REJ                  0   8699  100.000000
#       conn_state_RSTRH                  0   8699  100.000000
#      resp_pkts_bin_1.0                  0   8699  100.000000
#  resp_ip_bytes_bin_5.0                  0   8699  100.000000
#  resp_ip_bytes_bin_2.0                  0   8699  100.000000
#     resp_bytes_bin_5.0                  0   8699  100.000000
#     resp_bytes_bin_2.0                  0   8699  100.000000
#      history_Hs^ADTaFf                  0   8699  100.000000
#   history_Hs^ADTdttFaf                  0   8699  100.000000
#       history_Hs^ADfFa                  0   8699  100.000000
#              history_Q                  0   8699  100.000000
#              history_R                  0   8699  100.000000
#             history_Dd                  0   8699  100.000000
#              history_F                  0   8699  100.000000
#             history_Fr                  0   8699  100.000000
#           history_SARh                  0   8699  100.000000
#              history_S                  0   8699  100.000000
#       history_SAhDTaFf                  0   8699  100.000000
#              proto_tcp                  1   8699  100.000000
#            history_Arr                  0   8699  100.000000
#              history_A                  0   8699  100.000000
#              proto_udp                  0   8699  100.000000
#       history_ShADadfF                  0   8699  100.000000
#   history_ShADTdttaGFf                  0   8699  100.000000
#   history_ShADTdttaFTf                  0   8699  100.000000
#   history_ShADTdttTatR                  0   8699  100.000000
# history_ShADTdttTatFgf                  0   8699  100.000000
#  history_ShADTdttgaFTf                  0   8699  100.000000
#   history_ShADTdttFgaf                  0   8699  100.000000
# history_ShADTdtTtTtFar                  0   8699  100.000000
# history_ShADTadtTtTtFr                  0   8699  100.000000
#      history_ShADTaFgf                  0   8699  100.000000
#     history_ShADTaFdrR                  0   8699  100.000000
#             history_Sh                  0   8699  100.000000
#            history_SRh                  0   8699  100.000000
#        history_SAhdfFa                  0   8699  100.000000
#           history_SAhR                  0   8699  100.000000
#       history_SAhDdfFa                  0   8699  100.000000
#       history_SAhDdFaf                  0   8699  100.000000
#         history_ShAdFf                  0   8699  100.000000
#   history_ShAdtDTatTFf                  0   8699  100.000000
#            history_ShR                  0   8699  100.000000
#             history_Sr                  0   8699  100.000000
#             history_^d                  0   8699  100.000000
#      history_^hSADadFf                  0   8699  100.000000
#        history_^hSADdR                  0   8699  100.000000
#           history_^hSR                  0   8699  100.000000
#        service_dce_rpc                  0   8699  100.000000
#           service_dhcp                  0   8699  100.000000
#            service_dns                  0   8699  100.000000
#            service_ftp                  0   8699  100.000000
#      history_ShAaGDdfF                  0   8699  100.000000
#      history_ShAdDFagf                  0   8699  100.000000
#       history_ShAdDaFf                  0   8699  100.000000
#        history_ShAdFaf                  0   8699  100.000000
#            service_ntp                  0   8699  100.000000
#       history_ShADaGFf                  0   8699  100.000000
#       history_ShADadFf                  0   8699  100.000000
#   history_ShADTdttaTFR                  0   8699  100.000000
#      history_ShADgdfFa                  0   8699  100.000000
#        history_ShADdfr                  0   8699  100.000000
#        history_ShADdfR                  0   8699  100.000000
#       history_ShADdfFa                  0   8699  100.000000
#      history_ShADdafFr                  0   8699  100.000000
#      history_ShADdTafF                  0   8699  100.000000
#      history_ShADdTaFf                  0   8699  100.000000
#       history_ShADdFar                  0   8699  100.000000
#       history_ShADdFaf                  0   8699  100.000000
#     history_ShADagdfFr                  0   8699  100.000000
#      history_ShADagdfF                  0   8699  100.000000
#       history_ShADadfR                  0   8699  100.000000
#   history_ShADTdttTafr                  0   8698   99.988504
#  history_ShADTdttTaFfR                  0   8698   99.988504
#   history_ShADTdttaTFf                  0   8698   99.988504
#     history_ShADTadtFf                  0   8698   99.988504
#   history_ShADTdttgFaf                  0   8697   99.977009
#   history_ShADTdtgtFaf                  0   8696   99.965513
#   missed_bytes_bin_6.0                  0   8694   99.942522
#      history_ShADTdttR                  0   8694   99.942522
#   missed_bytes_bin_2.0                  0   8694   99.942522
#        conn_state_RSTO                  0   8693   99.931027
#          conn_state_SF                  1   8692   99.919531
#   history_ShADTdttatFf                  0   8691   99.908035
#   missed_bytes_bin_1.0                  1   8689   99.885044
#  history_ShADTdttTatFf                  0   8670   99.666628
#      resp_pkts_bin_6.0                  0   8661   99.563168
#   history_ShADTdttTaFf                  0   8654   99.482699
#     history_ShADTdtFaf                  0   8647   99.402230
#           service_http                  0   8646   99.390735
#  orig_ip_bytes_bin_2.0                  0   8646   99.390735
#  orig_ip_bytes_bin_1.0                  0   8637   99.287274
#        service_unknown                  0   8637   99.287274
#  orig_ip_bytes_bin_5.0                  0   8628   99.183814
#       duration_bin_5.0                  0   8605   98.919416
#      orig_pkts_bin_2.0                  0   8585   98.689505
#     resp_bytes_bin_1.0                  0   8584   98.678009
#  resp_ip_bytes_bin_1.0                  0   8584   98.678009
#            service_ssl                  1   8584   98.678009
#      resp_pkts_bin_2.0                  0   8584   98.678009
#      orig_pkts_bin_5.0                  0   8549   98.275664
#    history_ShADTdttFaf                  1   8467   97.333027
#       duration_bin_4.0                  0   8430   96.907691
#       duration_bin_6.0                  0   8394   96.493850
#
#
# ====================================================================================================
# Analysis for 'Discovery'
# Total Samples: 13430
# ====================================================================================================
#                 Column  Most Common Value  Count  Percentage
#             local_resp                  0  13430  100.000000
#         src_port_bin_1                  0  13430  100.000000
#       duration_bin_5.0                  0  13430  100.000000
#      orig_pkts_bin_3.0                  0  13430  100.000000
#      orig_pkts_bin_5.0                  0  13430  100.000000
#      orig_pkts_bin_4.0                  0  13430  100.000000
#  orig_ip_bytes_bin_4.0                  0  13430  100.000000
#  orig_ip_bytes_bin_3.0                  0  13430  100.000000
#     orig_bytes_bin_2.0                  0  13430  100.000000
#   missed_bytes_bin_6.0                  0  13430  100.000000
#     resp_bytes_bin_3.0                  0  13430  100.000000
#  orig_ip_bytes_bin_5.0                  0  13430  100.000000
#           history_SARh                  0  13430  100.000000
#              history_R                  0  13430  100.000000
#      resp_pkts_bin_6.0                  0  13430  100.000000
#      resp_pkts_bin_4.0                  0  13430  100.000000
#      resp_pkts_bin_3.0                  0  13430  100.000000
#      resp_pkts_bin_2.0                  0  13430  100.000000
#      resp_pkts_bin_1.0                  1  13430  100.000000
#  resp_ip_bytes_bin_5.0                  0  13430  100.000000
#  resp_ip_bytes_bin_4.0                  0  13430  100.000000
#  resp_ip_bytes_bin_3.0                  0  13430  100.000000
#  resp_ip_bytes_bin_2.0                  0  13430  100.000000
#  resp_ip_bytes_bin_1.0                  1  13430  100.000000
#     resp_bytes_bin_5.0                  0  13430  100.000000
#     resp_bytes_bin_4.0                  0  13430  100.000000
#       history_Hs^ADfFa                  0  13430  100.000000
#              history_Q                  0  13430  100.000000
#      history_Hs^ADTaFf                  0  13430  100.000000
#   history_Hs^ADTdttFaf                  0  13430  100.000000
#              history_D                  0  13430  100.000000
#         conn_state_SHR                  0  13430  100.000000
#   history_ShADTdttaTFR                  0  13430  100.000000
#   history_ShADTdttgFaf                  0  13430  100.000000
#   history_ShADTdttaFTf                  0  13430  100.000000
#   history_ShADTdttTatR                  0  13430  100.000000
# history_ShADTdttTatFgf                  0  13430  100.000000
#  history_ShADTdttTatFf                  0  13430  100.000000
#   history_ShADTdttTafr                  0  13430  100.000000
#  history_ShADTdttTaFfR                  0  13430  100.000000
#   history_ShADTdttTaFf                  0  13430  100.000000
#   history_ShADTdttaGFf                  0  13430  100.000000
#      history_ShADTdttR                  0  13430  100.000000
#   history_ShADTdttFgaf                  0  13430  100.000000
#   history_ShADTdtgtFaf                  0  13430  100.000000
#    history_ShADTdttFaf                  0  13430  100.000000
#     history_ShADTdtFaf                  0  13430  100.000000
# history_ShADTadtTtTtFr                  0  13430  100.000000
#     history_ShADTadtFf                  0  13430  100.000000
# history_ShADTdtTtTtFar                  0  13430  100.000000
#      history_ShADTaFgf                  0  13430  100.000000
#     history_ShADTaFdrR                  0  13430  100.000000
#            history_SRh                  0  13430  100.000000
#             history_Sh                  0  13430  100.000000
#        history_SAhdfFa                  0  13430  100.000000
#       history_SAhDdfFa                  0  13430  100.000000
#       history_SAhDdFaf                  0  13430  100.000000
#       history_SAhDTaFf                  0  13430  100.000000
#           service_dhcp                  0  13430  100.000000
#            service_ntp                  0  13430  100.000000
#           history_^hSR                  0  13430  100.000000
#       history_ShADdFaf                  0  13430  100.000000
#      history_ShADdTafF                  0  13430  100.000000
#       history_ShAdDaFf                  0  13430  100.000000
#      history_ShAaGDdfF                  0  13430  100.000000
#      history_ShADdafFr                  0  13430  100.000000
#             history_^d                  0  13430  100.000000
#      history_^hSADadFf                  0  13430  100.000000
#   history_ShAdtDTatTFf                  0  13430  100.000000
#        history_^hSADdR                  0  13430  100.000000
#        history_ShAdFaf                  0  13430  100.000000
#       history_ShADdFar                  0  13430  100.000000
#     history_ShADagdfFr                  0  13430  100.000000
#       history_ShADadfR                  0  13430  100.000000
#  history_ShADTdttgaFTf                  0  13430  100.000000
#   history_ShADTdttatFf                  0  13430  100.000000
#   history_ShADTdttaTFf                  0  13430  100.000000
#         conn_state_OTH                  0  13429   99.992554
#            service_ftp                  0  13429   99.992554
#     resp_bytes_bin_2.0                  0  13429   99.992554
#       duration_bin_6.0                  0  13429   99.992554
#     orig_bytes_bin_6.0                  0  13429   99.992554
#              history_A                  0  13429   99.992554
#            history_Arr                  0  13429   99.992554
#   missed_bytes_bin_4.0                  0  13429   99.992554
#      orig_pkts_bin_1.0                  1  13429   99.992554
#      orig_pkts_bin_2.0                  0  13429   99.992554
#       history_ShADadFf                  0  13429   99.992554
#           history_SAhR                  0  13429   99.992554
#       history_ShADaGFf                  0  13429   99.992554
#        history_ShADdfR                  0  13429   99.992554
#         history_ShAdFf                  0  13429   99.992554
#        service_dce_rpc                  0  13429   99.992554
#      history_ShAdDFagf                  0  13429   99.992554
#        history_ShADdfr                  0  13429   99.992554
#      history_ShADdTaFf                  0  13429   99.992554
#      history_ShADgdfFa                  0  13429   99.992554
#       duration_bin_4.0                  0  13428   99.985108
#      history_ShADagdfF                  0  13428   99.985108
#       history_ShADadfF                  0  13428   99.985108
#  orig_ip_bytes_bin_1.0                  1  13428   99.985108
#  orig_ip_bytes_bin_2.0                  0  13428   99.985108
#       conn_state_RSTRH                  0  13428   99.985108
#       duration_bin_2.0                  0  13428   99.985108
#             history_Fr                  0  13428   99.985108
#   missed_bytes_bin_2.0                  0  13427   99.977662
#       history_ShADdfFa                  0  13427   99.977662
#            service_ssl                  0  13427   99.977662
#            history_ShR                  0  13426   99.970216
#       duration_bin_3.0                  0  13426   99.970216
#   missed_bytes_bin_1.0                  1  13425   99.962770
#           service_http                  0  13418   99.910648
#        conn_state_RSTO                  0  13415   99.888310
#             history_Dd                  0  13415   99.888310
#              proto_tcp                  1  13415   99.888310
#              proto_udp                  0  13415   99.888310
#            service_dns                  0  13415   99.888310
#          conn_state_SF                  0  13396   99.746835
#        service_unknown                  1  13396   99.746835
#          conn_state_SH                  0  13282   98.897990
#              history_F                  0  13282   98.897990
#        dest_port_bin_1                  0  13041   97.103500
#
#
# ====================================================================================================
# Analysis for 'Reconnaissance'
# Total Samples: 2037
# ====================================================================================================
#                 Column  Most Common Value  Count  Percentage
#             local_resp                  0   2037  100.000000
#         src_port_bin_1                  0   2037  100.000000
#       duration_bin_4.0                  0   2037  100.000000
#  orig_ip_bytes_bin_4.0                  0   2037  100.000000
#       duration_bin_5.0                  0   2037  100.000000
#       duration_bin_6.0                  0   2037  100.000000
#   missed_bytes_bin_1.0                  1   2037  100.000000
#   missed_bytes_bin_4.0                  0   2037  100.000000
#   missed_bytes_bin_2.0                  0   2037  100.000000
#   missed_bytes_bin_6.0                  0   2037  100.000000
#     orig_bytes_bin_6.0                  0   2037  100.000000
#  orig_ip_bytes_bin_3.0                  0   2037  100.000000
#  orig_ip_bytes_bin_5.0                  0   2037  100.000000
#      resp_pkts_bin_3.0                  0   2037  100.000000
#     resp_bytes_bin_5.0                  0   2037  100.000000
#     resp_bytes_bin_3.0                  0   2037  100.000000
#     resp_bytes_bin_4.0                  0   2037  100.000000
#      orig_pkts_bin_4.0                  0   2037  100.000000
#      orig_pkts_bin_5.0                  0   2037  100.000000
#              history_Q                  0   2037  100.000000
#            history_Arr                  0   2037  100.000000
#   history_Hs^ADTdttFaf                  0   2037  100.000000
#      history_Hs^ADTaFf                  0   2037  100.000000
#       history_Hs^ADfFa                  0   2037  100.000000
#         conn_state_SHR                  0   2037  100.000000
#  resp_ip_bytes_bin_3.0                  0   2037  100.000000
#  resp_ip_bytes_bin_4.0                  0   2037  100.000000
#  resp_ip_bytes_bin_5.0                  0   2037  100.000000
#             history_Fr                  0   2037  100.000000
#       conn_state_RSTRH                  0   2037  100.000000
#      resp_pkts_bin_4.0                  0   2037  100.000000
#   history_ShADTdttTaFf                  0   2037  100.000000
#      history_ShADTdttR                  0   2037  100.000000
#   history_ShADTdttFgaf                  0   2037  100.000000
#   history_ShADTdttTatR                  0   2037  100.000000
#    history_ShADTdttFaf                  0   2037  100.000000
#   history_ShADTdtgtFaf                  0   2037  100.000000
#     history_ShADTdtFaf                  0   2037  100.000000
# history_ShADTadtTtTtFr                  0   2037  100.000000
#     history_ShADTadtFf                  0   2037  100.000000
#      history_ShADTaFgf                  0   2037  100.000000
#     history_ShADTaFdrR                  0   2037  100.000000
#             history_Sh                  0   2037  100.000000
#            history_SRh                  0   2037  100.000000
#        history_SAhdfFa                  0   2037  100.000000
#           history_SAhR                  0   2037  100.000000
#       history_SAhDdfFa                  0   2037  100.000000
#       history_SAhDdFaf                  0   2037  100.000000
#       history_SAhDTaFf                  0   2037  100.000000
#           history_SARh                  0   2037  100.000000
#              history_R                  0   2037  100.000000
#            service_ntp                  0   2037  100.000000
#       history_ShADadfR                  0   2037  100.000000
#     history_ShADagdfFr                  0   2037  100.000000
#      history_ShADagdfF                  0   2037  100.000000
#       history_ShADdFaf                  0   2037  100.000000
#       history_ShADdFar                  0   2037  100.000000
#      history_ShADdTafF                  0   2037  100.000000
#      history_ShADdTaFf                  0   2037  100.000000
#      history_ShADgdfFa                  0   2037  100.000000
#        history_ShADdfr                  0   2037  100.000000
#      history_ShADdafFr                  0   2037  100.000000
#        history_ShADdfR                  0   2037  100.000000
#      history_ShAaGDdfF                  0   2037  100.000000
#         history_ShAdFf                  0   2037  100.000000
#       history_ShAdDaFf                  0   2037  100.000000
#      history_ShAdDFagf                  0   2037  100.000000
#             history_^d                  0   2037  100.000000
#           service_dhcp                  0   2037  100.000000
#           history_^hSR                  0   2037  100.000000
#      history_^hSADadFf                  0   2037  100.000000
#  history_ShADTdttTaFfR                  0   2037  100.000000
#   history_ShADTdttTafr                  0   2037  100.000000
#  history_ShADTdttTatFf                  0   2037  100.000000
# history_ShADTdttTatFgf                  0   2037  100.000000
#   history_ShADTdttaTFf                  0   2037  100.000000
#   history_ShADTdttaFTf                  0   2037  100.000000
#   history_ShADTdttaGFf                  0   2037  100.000000
#   history_ShADTdttaTFR                  0   2037  100.000000
#   history_ShADTdttgFaf                  0   2037  100.000000
#   history_ShADTdttatFf                  0   2037  100.000000
#  history_ShADTdttgaFTf                  0   2037  100.000000
#       history_ShADaGFf                  0   2037  100.000000
#        history_^hSADdR                  0   2037  100.000000
#  resp_ip_bytes_bin_1.0                  1   2036   99.950908
#       duration_bin_2.0                  0   2036   99.950908
#     orig_bytes_bin_2.0                  0   2036   99.950908
#      resp_pkts_bin_6.0                  0   2036   99.950908
# history_ShADTdtTtTtFar                  0   2036   99.950908
#       history_ShADdfFa                  0   2036   99.950908
#        service_dce_rpc                  0   2036   99.950908
#            service_ssl                  0   2036   99.950908
#            service_ftp                  0   2036   99.950908
#        history_ShAdFaf                  0   2036   99.950908
#   history_ShAdtDTatTFf                  0   2036   99.950908
#      orig_pkts_bin_3.0                  0   2036   99.950908
#  resp_ip_bytes_bin_2.0                  0   2036   99.950908
#       history_ShADadFf                  0   2035   99.901816
#     resp_bytes_bin_2.0                  0   2035   99.901816
#       history_ShADadfF                  0   2034   99.852725
#       duration_bin_3.0                  0   2032   99.754541
#           service_http                  0   2031   99.705449
#  orig_ip_bytes_bin_2.0                  0   2031   99.705449
#  orig_ip_bytes_bin_1.0                  1   2030   99.656357
#              history_D                  0   2015   98.919980
#              history_F                  0   1997   98.036328
#          conn_state_SH                  0   1997   98.036328
#            history_ShR                  0   1989   97.643594
#      orig_pkts_bin_2.0                  0   1988   97.594502
#        conn_state_RSTO                  0   1988   97.594502
#      resp_pkts_bin_2.0                  0   1987   97.545410
#      resp_pkts_bin_1.0                  1   1986   97.496318
#      orig_pkts_bin_1.0                  1   1986   97.496318
#         conn_state_OTH                  0   1932   94.845361
#              history_A                  0   1932   94.845361
#
#
# ====================================================================================================
# Analysis for 'none'
# Total Samples: 27403
# ====================================================================================================
#                 Column  Most Common Value  Count  Percentage
#   missed_bytes_bin_4.0                  0  27403  100.000000
#   missed_bytes_bin_6.0                  0  27403  100.000000
#   missed_bytes_bin_1.0                  1  27403  100.000000
#   missed_bytes_bin_2.0                  0  27403  100.000000
#  orig_ip_bytes_bin_3.0                  0  27403  100.000000
#  orig_ip_bytes_bin_4.0                  0  27403  100.000000
#     resp_bytes_bin_3.0                  0  27403  100.000000
#     resp_bytes_bin_2.0                  0  27403  100.000000
#      orig_pkts_bin_3.0                  0  27403  100.000000
#      orig_pkts_bin_4.0                  0  27403  100.000000
#      orig_pkts_bin_5.0                  0  27403  100.000000
#  orig_ip_bytes_bin_5.0                  0  27403  100.000000
#     orig_bytes_bin_6.0                  0  27403  100.000000
#     orig_bytes_bin_2.0                  0  27403  100.000000
#       history_Hs^ADfFa                  0  27403  100.000000
#   history_Hs^ADTdttFaf                  0  27403  100.000000
#            history_Arr                  0  27403  100.000000
#       history_SAhDTaFf                  0  27403  100.000000
#           history_SARh                  0  27403  100.000000
#              history_R                  0  27403  100.000000
#              history_Q                  0  27403  100.000000
#        conn_state_RSTO                  0  27403  100.000000
#      resp_pkts_bin_4.0                  0  27403  100.000000
#      resp_pkts_bin_6.0                  0  27403  100.000000
#      resp_pkts_bin_3.0                  0  27403  100.000000
#  resp_ip_bytes_bin_5.0                  0  27403  100.000000
#  resp_ip_bytes_bin_4.0                  0  27403  100.000000
#  resp_ip_bytes_bin_3.0                  0  27403  100.000000
#  resp_ip_bytes_bin_2.0                  0  27403  100.000000
#  resp_ip_bytes_bin_1.0                  1  27403  100.000000
#     resp_bytes_bin_5.0                  0  27403  100.000000
#     resp_bytes_bin_4.0                  0  27403  100.000000
#      history_Hs^ADTaFf                  0  27403  100.000000
#       history_ShADadfF                  0  27403  100.000000
#       history_ShADaGFf                  0  27403  100.000000
#       history_ShADadFf                  0  27403  100.000000
#   history_ShADTdttgFaf                  0  27403  100.000000
#   history_ShADTdttatFf                  0  27403  100.000000
#   history_ShADTdttaTFf                  0  27403  100.000000
#  history_ShADTdttgaFTf                  0  27403  100.000000
#   history_ShADTdttaGFf                  0  27403  100.000000
#   history_ShADTdttaFTf                  0  27403  100.000000
#   history_ShADTdttTatR                  0  27403  100.000000
# history_ShADTdttTatFgf                  0  27403  100.000000
#  history_ShADTdttTatFf                  0  27403  100.000000
#   history_ShADTdttTafr                  0  27403  100.000000
#  history_ShADTdttTaFfR                  0  27403  100.000000
#   history_ShADTdttaTFR                  0  27403  100.000000
#   history_ShADTdttTaFf                  0  27403  100.000000
#      history_ShADTdttR                  0  27403  100.000000
#    history_ShADTdttFaf                  0  27403  100.000000
#   history_ShADTdttFgaf                  0  27403  100.000000
# history_ShADTdtTtTtFar                  0  27403  100.000000
#     history_ShADTdtFaf                  0  27403  100.000000
# history_ShADTadtTtTtFr                  0  27403  100.000000
#   history_ShADTdtgtFaf                  0  27403  100.000000
#     history_ShADTadtFf                  0  27403  100.000000
#      history_ShADTaFgf                  0  27403  100.000000
#     history_ShADTaFdrR                  0  27403  100.000000
#            history_SRh                  0  27403  100.000000
#        history_SAhdfFa                  0  27403  100.000000
#           history_SAhR                  0  27403  100.000000
#       history_SAhDdfFa                  0  27403  100.000000
#       history_SAhDdFaf                  0  27403  100.000000
#         history_ShAdFf                  0  27403  100.000000
#      history_ShADagdfF                  0  27403  100.000000
#     history_ShADagdfFr                  0  27403  100.000000
#       history_ShADdFaf                  0  27403  100.000000
#       history_ShADdFar                  0  27403  100.000000
#      history_ShADdTaFf                  0  27403  100.000000
#      history_ShADdTafF                  0  27403  100.000000
#      history_ShADdafFr                  0  27403  100.000000
#       history_ShADdfFa                  0  27403  100.000000
#        history_ShADdfR                  0  27403  100.000000
#        history_ShADdfr                  0  27403  100.000000
#      history_ShADgdfFa                  0  27403  100.000000
#      history_ShAaGDdfF                  0  27403  100.000000
#      history_ShAdDFagf                  0  27403  100.000000
#       history_ShAdDaFf                  0  27403  100.000000
#        history_ShAdFaf                  0  27403  100.000000
#            service_ssl                  0  27403  100.000000
#   history_ShAdtDTatTFf                  0  27403  100.000000
#            history_ShR                  0  27403  100.000000
#      history_^hSADadFf                  0  27403  100.000000
#           history_^hSR                  0  27403  100.000000
#        history_^hSADdR                  0  27403  100.000000
#            service_ftp                  0  27403  100.000000
#        service_dce_rpc                  0  27403  100.000000
#           service_http                  0  27403  100.000000
#       history_ShADadfR                  0  27403  100.000000
#      resp_pkts_bin_2.0                  0  27402   99.996351
#             history_Sh                  0  27402   99.996351
#             history_Fr                  0  27402   99.996351
#      resp_pkts_bin_1.0                  1  27402   99.996351
#        dest_port_bin_3                  0  27401   99.992702
#       conn_state_RSTRH                  0  27400   99.989052
#          conn_state_SH                  0  27387   99.941612
#       duration_bin_4.0                  0  27387   99.941612
#              history_F                  0  27387   99.941612
#           service_dhcp                  0  27383   99.927015
#         conn_state_OTH                  0  27380   99.916068
#              history_A                  0  27380   99.916068
#       duration_bin_6.0                  0  27358   99.835784
#  orig_ip_bytes_bin_1.0                  1  27349   99.802941
#  orig_ip_bytes_bin_2.0                  0  27349   99.802941
#            service_ntp                  0  27341   99.773747
#             history_^d                  0  27340   99.770098
#         conn_state_SHR                  0  27340   99.770098
#      orig_pkts_bin_1.0                  1  27301   99.627778
#      orig_pkts_bin_2.0                  0  27301   99.627778
#         src_port_bin_1                  0  27190   99.222713
#       duration_bin_5.0                  0  27188   99.215414
#       duration_bin_2.0                  0  27061   98.751961
#       duration_bin_3.0                  0  26769   97.686385
#              history_S                  0  26698   97.427289
#         conn_state_REJ                  0  26272   95.872715
#             history_Sr                  0  26272   95.872715
#        dest_port_bin_2                  0  26178   95.529687
#        dest_port_bin_1                  1  26176   95.522388
#              proto_tcp                  0  25523   93.139437
#              proto_udp                  1  25523   93.139437
#        service_unknown                  0  25445   92.854797
#            service_dns                  1  25363   92.555560
#     orig_bytes_bin_1.0                  1  25274   92.230778
#     resp_bytes_bin_0.0                  0  25274   92.230778
#     orig_bytes_bin_0.0                  0  25274   92.230778
#     resp_bytes_bin_1.0                  1  25274   92.230778
#       duration_bin_0.0                  0  25274   92.230778

# %%
print ("Resource Development combined - test set")
for tactic in sorted(set(df7["label_tactic"])):
    analyze_label_characteristics("label_tactic",tactic,df7)
    print("\n")
# Out:
# Resource Development combined - test set
# ====================================================================================================
# Analysis for 'Credential Access'
# Total Samples: 8699
# ====================================================================================================
#                Column  Most Common Value  Count  Percentage
#            local_resp                  0   8699  100.000000
#        src_port_bin_1                  0   8699  100.000000
#        src_port_bin_2                  1   8699  100.000000
#        src_port_bin_3                  0   8699  100.000000
#       dest_port_bin_1                  0   8699  100.000000
#       dest_port_bin_2                  1   8699  100.000000
#       dest_port_bin_3                  0   8699  100.000000
#      duration_bin_0.0                  0   8699  100.000000
#  missed_bytes_bin_3.0                  0   8699  100.000000
#      conn_state_RSTRH                  0   8699  100.000000
#    orig_bytes_bin_0.0                  0   8699  100.000000
#    orig_bytes_bin_1.0                  1   8699  100.000000
#     orig_pkts_bin_1.0                  0   8699  100.000000
#    resp_bytes_bin_0.0                  0   8699  100.000000
#        conn_state_REJ                  0   8699  100.000000
#             proto_tcp                  1   8699  100.000000
#            history_Ar                  0   8699  100.000000
#             proto_udp                  0   8699  100.000000
#         conn_state_S0                  0   8699  100.000000
#         conn_state_SH                  0   8699  100.000000
#        conn_state_SHR                  0   8699  100.000000
#     resp_pkts_bin_5.0                  0   8699  100.000000
#     resp_pkts_bin_1.0                  0   8699  100.000000
# history_ShADTdttgaFTf                  0   8699  100.000000
#      history_ShADadFf                  0   8699  100.000000
#  history_ShADTadttTFf                  0   8699  100.000000
#     history_ShADTaFgf                  0   8699  100.000000
#    history_ShADTaFdrR                  0   8699  100.000000
#      history_ShADTaFf                  0   8699  100.000000
#            history_Sh                  0   8699  100.000000
#           history_SRh                  0   8699  100.000000
#       history_SAhDfFa                  0   8699  100.000000
#  history_SAhDTdttgFaf                  0   8699  100.000000
#      history_SAhDTaFf                  0   8699  100.000000
#             history_S                  0   8699  100.000000
#             history_Q                  0   8699  100.000000
# history_Hs^ADTdttTaFf                  0   8699  100.000000
#             history_F                  0   8699  100.000000
#            history_Dd                  0   8699  100.000000
#             history_D                  0   8699  100.000000
#           history_Arr                  0   8699  100.000000
#           service_dns                  0   8699  100.000000
#       history_ShAdfFa                  0   8699  100.000000
#           history_ShR                  0   8699  100.000000
#            history_Sr                  0   8699  100.000000
#            history_^d                  0   8699  100.000000
#           history_^dD                  0   8699  100.000000
#            history_^r                  0   8699  100.000000
#       service_dce_rpc                  0   8699  100.000000
#           service_ntp                  0   8699  100.000000
#           service_ftp                  0   8699  100.000000
#        service_gssapi                  0   8699  100.000000
#       service_krb_tcp                  0   8699  100.000000
#      history_ShAdDaFf                  0   8699  100.000000
#     history_ShAaGDdfF                  0   8699  100.000000
#       history_ShAdFaf                  0   8699  100.000000
#        history_ShAdFf                  0   8699  100.000000
#       history_ShADdfr                  0   8699  100.000000
#     history_ShADdTafF                  0   8699  100.000000
#  history_ShADTdttaTFR                  0   8699  100.000000
#  history_ShADTdttTatR                  0   8699  100.000000
#          history_ShAR                  0   8699  100.000000
#     history_ShADgdFaf                  0   8699  100.000000
#       history_ShADfFa                  0   8699  100.000000
#       history_ShADdgR                  0   8699  100.000000
#        history_ShADar                  0   8699  100.000000
#     history_ShADagdfF                  0   8699  100.000000
#     history_ShADdTaFf                  0   8699  100.000000
#      history_ShADdFar                  0   8699  100.000000
#     history_ShADadfFr                  0   8699  100.000000
#      history_ShADadfF                  0   8699  100.000000
#  history_ShADTdttTafr                  0   8698   99.988504
#  history_ShADTdttaTFf                  0   8698   99.988504
#  history_ShADTdttaGfF                  0   8698   99.988504
#  history_ShADTdttgFaf                  0   8697   99.977009
#  history_ShADTdtgtFaf                  0   8696   99.965513
#   history_SAhDTdttFaf                  0   8696   99.965513
#  history_ShADTdttFTaf                  0   8695   99.954018
#         conn_state_SF                  1   8692   99.919531
# orig_ip_bytes_bin_6.0                  0   8692   99.919531
#   history_ShADTdttaFf                  0   8692   99.919531
#  missed_bytes_bin_1.0                  1   8689   99.885044
# history_ShADTdttTatFf                  0   8670   99.666628
#     orig_pkts_bin_6.0                  0   8669   99.655133
# resp_ip_bytes_bin_6.0                  0   8661   99.563168
#    resp_bytes_bin_6.0                  0   8661   99.563168
#     resp_pkts_bin_6.0                  0   8661   99.563168
#  history_ShADTdttTaFf                  0   8654   99.482699
#    history_ShADTdtFaf                  0   8647   99.402230
# orig_ip_bytes_bin_2.0                  0   8646   99.390735
#          service_http                  0   8646   99.390735
#       service_unknown                  0   8637   99.287274
# orig_ip_bytes_bin_1.0                  0   8637   99.287274
#        history_ShAFaf                  0   8637   99.287274
# orig_ip_bytes_bin_5.0                  0   8615   99.034372
#      duration_bin_5.0                  0   8607   98.942407
#     orig_pkts_bin_2.0                  0   8585   98.689505
#    resp_bytes_bin_1.0                  0   8584   98.678009
#     resp_pkts_bin_2.0                  0   8584   98.678009
#           service_ssl                  1   8584   98.678009
# resp_ip_bytes_bin_1.0                  0   8584   98.678009
#     orig_pkts_bin_5.0                  0   8549   98.275664
#   history_ShADTdttFaf                  1   8467   97.333027
#      duration_bin_4.0                  0   8435   96.965168
#      duration_bin_6.0                  0   8402   96.585814
#
#
# ====================================================================================================
# Analysis for 'Discovery'
# Total Samples: 13431
# ====================================================================================================
#                Column  Most Common Value  Count  Percentage
#            local_resp                  0  13431  100.000000
#        src_port_bin_1                  0  13431  100.000000
#      duration_bin_5.0                  0  13431  100.000000
# orig_ip_bytes_bin_6.0                  0  13431  100.000000
# orig_ip_bytes_bin_3.0                  0  13431  100.000000
# orig_ip_bytes_bin_4.0                  0  13431  100.000000
# orig_ip_bytes_bin_5.0                  0  13431  100.000000
#  missed_bytes_bin_3.0                  0  13431  100.000000
#     resp_pkts_bin_4.0                  0  13431  100.000000
#     resp_pkts_bin_5.0                  0  13431  100.000000
#     resp_pkts_bin_6.0                  0  13431  100.000000
#        conn_state_SHR                  0  13431  100.000000
#     resp_pkts_bin_2.0                  0  13431  100.000000
#     orig_pkts_bin_6.0                  0  13431  100.000000
#     orig_pkts_bin_3.0                  0  13431  100.000000
#     orig_pkts_bin_4.0                  0  13431  100.000000
#    resp_bytes_bin_3.0                  0  13431  100.000000
#    resp_bytes_bin_4.0                  0  13431  100.000000
#     orig_pkts_bin_5.0                  0  13431  100.000000
# resp_ip_bytes_bin_6.0                  0  13431  100.000000
# resp_ip_bytes_bin_4.0                  0  13431  100.000000
# resp_ip_bytes_bin_3.0                  0  13431  100.000000
# resp_ip_bytes_bin_1.0                  1  13431  100.000000
#    resp_bytes_bin_6.0                  0  13431  100.000000
#     resp_pkts_bin_3.0                  0  13431  100.000000
#     resp_pkts_bin_1.0                  1  13431  100.000000
#    history_ShADTdtFaf                  0  13431  100.000000
#  history_ShADTdtgtFaf                  0  13431  100.000000
#  history_ShADTdttFTaf                  0  13431  100.000000
#      history_ShADTaFf                  0  13431  100.000000
#            history_Sh                  0  13431  100.000000
#    history_ShADTaFdrR                  0  13431  100.000000
#      history_SAhDTaFf                  0  13431  100.000000
#   history_SAhDTdttFaf                  0  13431  100.000000
#  history_SAhDTdttgFaf                  0  13431  100.000000
#           history_SRh                  0  13431  100.000000
#             history_Q                  0  13431  100.000000
# history_Hs^ADTdttTaFf                  0  13431  100.000000
#             history_D                  0  13431  100.000000
#            history_Ar                  0  13431  100.000000
#            history_^d                  0  13431  100.000000
#           service_ntp                  0  13431  100.000000
#        service_gssapi                  0  13431  100.000000
#            history_^r                  0  13431  100.000000
#       history_ShAdfFa                  0  13431  100.000000
#     history_ShAaGDdfF                  0  13431  100.000000
#     history_ShADgdFaf                  0  13431  100.000000
#       history_ShADdgR                  0  13431  100.000000
#       history_ShAdFaf                  0  13431  100.000000
#           history_^dD                  0  13431  100.000000
# history_ShADTdttgaFTf                  0  13431  100.000000
#        history_ShAFaf                  0  13431  100.000000
#      history_ShAdDaFf                  0  13431  100.000000
#     history_ShADdTafF                  0  13431  100.000000
#  history_ShADTadttTFf                  0  13431  100.000000
#     history_ShADTaFgf                  0  13431  100.000000
# history_ShADTdttTatFf                  0  13431  100.000000
#  history_ShADTdttTatR                  0  13431  100.000000
#   history_ShADTdttaFf                  0  13431  100.000000
#  history_ShADTdttaGfF                  0  13431  100.000000
#  history_ShADTdttaTFR                  0  13431  100.000000
#   history_ShADTdttFaf                  0  13431  100.000000
#  history_ShADTdttTaFf                  0  13431  100.000000
#  history_ShADTdttTafr                  0  13431  100.000000
#  history_ShADTdttgFaf                  0  13431  100.000000
#  history_ShADTdttaTFf                  0  13431  100.000000
#      history_ShADdFar                  0  13431  100.000000
#     history_ShADadfFr                  0  13431  100.000000
#     orig_pkts_bin_1.0                  1  13430   99.992555
#     orig_pkts_bin_2.0                  0  13430   99.992555
#           service_ftp                  0  13430   99.992555
#      duration_bin_6.0                  0  13430   99.992555
#     history_ShADdTaFf                  0  13430   99.992555
#        history_ShAdFf                  0  13430   99.992555
#       history_ShADdfr                  0  13430   99.992555
#       history_SAhDfFa                  0  13430   99.992555
#           history_Arr                  0  13430   99.992555
#       service_dce_rpc                  0  13430   99.992555
#      history_ShADadFf                  0  13430   99.992555
#     history_ShADagdfF                  0  13429   99.985109
#      duration_bin_4.0                  0  13429   99.985109
#      duration_bin_2.0                  0  13429   99.985109
#      conn_state_RSTRH                  0  13429   99.985109
#      history_ShADadfF                  0  13429   99.985109
#       service_krb_tcp                  0  13429   99.985109
#        history_ShADar                  0  13429   99.985109
# orig_ip_bytes_bin_2.0                  0  13429   99.985109
# orig_ip_bytes_bin_1.0                  1  13429   99.985109
#           service_ssl                  0  13428   99.977664
#       history_ShADfFa                  0  13428   99.977664
#           history_ShR                  0  13427   99.970218
#      duration_bin_3.0                  0  13427   99.970218
#  missed_bytes_bin_1.0                  1  13426   99.962773
#          history_ShAR                  0  13422   99.932991
#          service_http                  0  13419   99.910654
#             proto_tcp                  1  13416   99.888318
#           service_dns                  0  13416   99.888318
#            history_Dd                  0  13416   99.888318
#             proto_udp                  0  13416   99.888318
#         conn_state_SF                  0  13397   99.746854
#       service_unknown                  1  13397   99.746854
#         conn_state_SH                  0  13283   98.898072
#             history_F                  0  13283   98.898072
#       dest_port_bin_1                  0  13042   97.103715
#
#
# ====================================================================================================
# Analysis for 'Resource Development'
# Total Samples: 2723
# ====================================================================================================
#                Column  Most Common Value  Count  Percentage
#            local_resp                  0   2723  100.000000
#        src_port_bin_1                  0   2723  100.000000
#      duration_bin_2.0                  0   2723  100.000000
#      duration_bin_5.0                  0   2723  100.000000
#      duration_bin_4.0                  0   2723  100.000000
#      duration_bin_3.0                  0   2723  100.000000
#      duration_bin_6.0                  0   2723  100.000000
# orig_ip_bytes_bin_2.0                  0   2723  100.000000
#  missed_bytes_bin_3.0                  0   2723  100.000000
#  missed_bytes_bin_1.0                  1   2723  100.000000
# orig_ip_bytes_bin_3.0                  0   2723  100.000000
# orig_ip_bytes_bin_4.0                  0   2723  100.000000
# orig_ip_bytes_bin_1.0                  1   2723  100.000000
#     orig_pkts_bin_3.0                  0   2723  100.000000
#     orig_pkts_bin_2.0                  0   2723  100.000000
#     orig_pkts_bin_1.0                  1   2723  100.000000
# orig_ip_bytes_bin_6.0                  0   2723  100.000000
# orig_ip_bytes_bin_5.0                  0   2723  100.000000
#      conn_state_RSTRH                  0   2723  100.000000
#         conn_state_SH                  0   2723  100.000000
#     resp_pkts_bin_2.0                  0   2723  100.000000
#     resp_pkts_bin_3.0                  0   2723  100.000000
#     resp_pkts_bin_4.0                  0   2723  100.000000
#     orig_pkts_bin_4.0                  0   2723  100.000000
#     orig_pkts_bin_5.0                  0   2723  100.000000
#     orig_pkts_bin_6.0                  0   2723  100.000000
#    resp_bytes_bin_4.0                  0   2723  100.000000
#    resp_bytes_bin_3.0                  0   2723  100.000000
# resp_ip_bytes_bin_1.0                  1   2723  100.000000
#    resp_bytes_bin_6.0                  0   2723  100.000000
# resp_ip_bytes_bin_3.0                  0   2723  100.000000
# resp_ip_bytes_bin_4.0                  0   2723  100.000000
#     resp_pkts_bin_1.0                  1   2723  100.000000
# resp_ip_bytes_bin_6.0                  0   2723  100.000000
#             proto_udp                  0   2723  100.000000
#            history_Ar                  0   2723  100.000000
#             proto_tcp                  1   2723  100.000000
#        conn_state_SHR                  0   2723  100.000000
#     resp_pkts_bin_6.0                  0   2723  100.000000
#     resp_pkts_bin_5.0                  0   2723  100.000000
#        conn_state_REJ                  0   2723  100.000000
#            history_Sh                  0   2723  100.000000
#   history_SAhDTdttFaf                  0   2723  100.000000
#      history_SAhDTaFf                  0   2723  100.000000
#             history_Q                  0   2723  100.000000
# history_Hs^ADTdttTaFf                  0   2723  100.000000
#             history_F                  0   2723  100.000000
#            history_Dd                  0   2723  100.000000
#             history_D                  0   2723  100.000000
#           history_Arr                  0   2723  100.000000
#           service_ssl                  0   2723  100.000000
#     history_ShADagdfF                  0   2723  100.000000
#        history_ShADar                  0   2723  100.000000
#      history_ShADdFar                  0   2723  100.000000
#     history_ShADdTafF                  0   2723  100.000000
#     history_ShADdTaFf                  0   2723  100.000000
#       history_ShADdfr                  0   2723  100.000000
#       history_ShADdgR                  0   2723  100.000000
#          history_ShAR                  0   2723  100.000000
#  history_SAhDTdttgFaf                  0   2723  100.000000
#       history_SAhDfFa                  0   2723  100.000000
#           history_SRh                  0   2723  100.000000
#      history_ShADTaFf                  0   2723  100.000000
#    history_ShADTaFdrR                  0   2723  100.000000
#     history_ShADTaFgf                  0   2723  100.000000
#  history_ShADTadttTFf                  0   2723  100.000000
#  history_ShADTdttTatR                  0   2723  100.000000
#    history_ShADTdtFaf                  0   2723  100.000000
#  history_ShADTdtgtFaf                  0   2723  100.000000
#  history_ShADTdttFTaf                  0   2723  100.000000
#   history_ShADTdttFaf                  0   2723  100.000000
#  history_ShADTdttTaFf                  0   2723  100.000000
#  history_ShADTdttTafr                  0   2723  100.000000
# history_ShADTdttTatFf                  0   2723  100.000000
#  history_ShADTdttaTFf                  0   2723  100.000000
#   history_ShADTdttaFf                  0   2723  100.000000
#  history_ShADTdttaGfF                  0   2723  100.000000
#  history_ShADTdttaTFR                  0   2723  100.000000
# history_ShADTdttgaFTf                  0   2723  100.000000
#  history_ShADTdttgFaf                  0   2723  100.000000
#      history_ShADadFf                  0   2723  100.000000
#     history_ShADadfFr                  0   2723  100.000000
#           service_ntp                  0   2723  100.000000
#       history_ShAdfFa                  0   2723  100.000000
#            history_Sr                  0   2723  100.000000
#            history_^d                  0   2723  100.000000
#            history_^r                  0   2723  100.000000
#           history_^dD                  0   2723  100.000000
#       service_dce_rpc                  0   2723  100.000000
#           service_dns                  0   2723  100.000000
#        service_gssapi                  0   2723  100.000000
#       history_ShADfFa                  0   2723  100.000000
#     history_ShADgdFaf                  0   2723  100.000000
#        history_ShAFaf                  0   2723  100.000000
#      history_ShAdDaFf                  0   2723  100.000000
#     history_ShAaGDdfF                  0   2723  100.000000
#       history_ShAdFaf                  0   2723  100.000000
#        history_ShAdFf                  0   2723  100.000000
#       service_krb_tcp                  0   2723  100.000000
#           service_ftp                  0   2723  100.000000
#         conn_state_SF                  0   2722   99.963276
#      history_ShADadfF                  0   2722   99.963276
#       service_unknown                  1   2722   99.963276
#          service_http                  0   2722   99.963276
#           history_ShR                  0   2721   99.926552
#      duration_bin_0.0                  1   2720   99.889827
#    orig_bytes_bin_1.0                  0   2720   99.889827
#         conn_state_S0                  1   2720   99.889827
#    resp_bytes_bin_0.0                  1   2720   99.889827
#    resp_bytes_bin_1.0                  0   2720   99.889827
#    orig_bytes_bin_0.0                  1   2720   99.889827
#      duration_bin_1.0                  0   2720   99.889827
#             history_S                  1   2720   99.889827
#       dest_port_bin_1                  0   2689   98.751377
#
#
# ====================================================================================================
# Analysis for 'none'
# Total Samples: 27403
# ====================================================================================================
#                Column  Most Common Value  Count  Percentage
#  missed_bytes_bin_1.0                  1  27403  100.000000
#  missed_bytes_bin_3.0                  0  27403  100.000000
# resp_ip_bytes_bin_6.0                  0  27403  100.000000
#     resp_pkts_bin_3.0                  0  27403  100.000000
#     resp_pkts_bin_5.0                  0  27403  100.000000
#     resp_pkts_bin_4.0                  0  27403  100.000000
#     orig_pkts_bin_3.0                  0  27403  100.000000
#     orig_pkts_bin_5.0                  0  27403  100.000000
#     orig_pkts_bin_6.0                  0  27403  100.000000
#    resp_bytes_bin_4.0                  0  27403  100.000000
#    resp_bytes_bin_3.0                  0  27403  100.000000
# orig_ip_bytes_bin_6.0                  0  27403  100.000000
# orig_ip_bytes_bin_5.0                  0  27403  100.000000
# orig_ip_bytes_bin_4.0                  0  27403  100.000000
#     resp_pkts_bin_6.0                  0  27403  100.000000
# resp_ip_bytes_bin_3.0                  0  27403  100.000000
# resp_ip_bytes_bin_1.0                  1  27403  100.000000
#    resp_bytes_bin_6.0                  0  27403  100.000000
# resp_ip_bytes_bin_4.0                  0  27403  100.000000
#      history_ShADadFf                  0  27403  100.000000
#  history_ShADTdttgFaf                  0  27403  100.000000
# history_ShADTdttgaFTf                  0  27403  100.000000
# history_ShADTdttTatFf                  0  27403  100.000000
#  history_ShADTdttTafr                  0  27403  100.000000
#  history_ShADTdttTaFf                  0  27403  100.000000
#  history_ShADTdttaTFf                  0  27403  100.000000
#  history_ShADTdttaTFR                  0  27403  100.000000
#  history_ShADTdttaGfF                  0  27403  100.000000
#   history_ShADTdttaFf                  0  27403  100.000000
#  history_ShADTdttTatR                  0  27403  100.000000
#  history_ShADTadttTFf                  0  27403  100.000000
#    history_ShADTdtFaf                  0  27403  100.000000
#  history_ShADTdtgtFaf                  0  27403  100.000000
#  history_ShADTdttFTaf                  0  27403  100.000000
#   history_ShADTdttFaf                  0  27403  100.000000
#     history_ShADTaFgf                  0  27403  100.000000
#      history_ShADTaFf                  0  27403  100.000000
#    history_ShADTaFdrR                  0  27403  100.000000
#   history_SAhDTdttFaf                  0  27403  100.000000
#  history_SAhDTdttgFaf                  0  27403  100.000000
#       history_SAhDfFa                  0  27403  100.000000
#           history_SRh                  0  27403  100.000000
# history_Hs^ADTdttTaFf                  0  27403  100.000000
#             history_Q                  0  27403  100.000000
#      history_SAhDTaFf                  0  27403  100.000000
#           history_Arr                  0  27403  100.000000
#        history_ShAdFf                  0  27403  100.000000
#       history_ShAdfFa                  0  27403  100.000000
#           history_ShR                  0  27403  100.000000
#           history_^dD                  0  27403  100.000000
#       service_dce_rpc                  0  27403  100.000000
#     history_ShADdTaFf                  0  27403  100.000000
#     history_ShADdTafF                  0  27403  100.000000
#       history_ShADdfr                  0  27403  100.000000
#       history_ShADdgR                  0  27403  100.000000
#       history_ShADfFa                  0  27403  100.000000
#     history_ShADgdFaf                  0  27403  100.000000
#        history_ShAFaf                  0  27403  100.000000
#          history_ShAR                  0  27403  100.000000
#     history_ShAaGDdfF                  0  27403  100.000000
#      history_ShAdDaFf                  0  27403  100.000000
#       history_ShAdFaf                  0  27403  100.000000
#           service_ssl                  0  27403  100.000000
#       service_krb_tcp                  0  27403  100.000000
#          service_http                  0  27403  100.000000
#           service_ftp                  0  27403  100.000000
#        service_gssapi                  0  27403  100.000000
#            history_^r                  0  27403  100.000000
#     history_ShADadfFr                  0  27403  100.000000
#      history_ShADadfF                  0  27403  100.000000
#        history_ShADar                  0  27403  100.000000
#     history_ShADagdfF                  0  27403  100.000000
#      history_ShADdFar                  0  27403  100.000000
#     resp_pkts_bin_1.0                  1  27402   99.996351
# orig_ip_bytes_bin_3.0                  0  27402   99.996351
#     resp_pkts_bin_2.0                  0  27402   99.996351
#            history_Sh                  0  27402   99.996351
#     orig_pkts_bin_4.0                  0  27402   99.996351
#      conn_state_RSTRH                  0  27400   99.989052
#       dest_port_bin_3                  0  27400   99.989052
#            history_Ar                  0  27400   99.989052
#             history_F                  0  27391   99.956209
#         conn_state_SH                  0  27391   99.956209
#      duration_bin_6.0                  0  27352   99.813889
# orig_ip_bytes_bin_2.0                  0  27348   99.799292
# orig_ip_bytes_bin_1.0                  1  27347   99.795643
#           service_ntp                  0  27345   99.788344
#        conn_state_SHR                  0  27344   99.784695
#            history_^d                  0  27344   99.784695
#      duration_bin_5.0                  0  27342   99.777397
#     orig_pkts_bin_2.0                  0  27294   99.602233
#     orig_pkts_bin_1.0                  1  27293   99.598584
#      duration_bin_4.0                  0  27217   99.321242
#        src_port_bin_1                  0  27191   99.226362
#      duration_bin_2.0                  0  27048   98.704521
#      duration_bin_3.0                  0  26754   97.631646
#             history_S                  0  26667   97.314163
#        conn_state_REJ                  0  26290   95.938401
#            history_Sr                  0  26290   95.938401
#       dest_port_bin_2                  0  26192   95.580776
#       dest_port_bin_1                  1  26189   95.569828
#             proto_tcp                  0  25514   93.106594
#             proto_udp                  1  25514   93.106594
#       service_unknown                  0  25429   92.796409
#           service_dns                  1  25350   92.508120
#    resp_bytes_bin_1.0                  1  25245   92.124950
#      duration_bin_0.0                  0  25245   92.124950
#    resp_bytes_bin_0.0                  0  25245   92.124950
#    orig_bytes_bin_0.0                  0  25245   92.124950
#    orig_bytes_bin_1.0                  1  25245   92.124950
